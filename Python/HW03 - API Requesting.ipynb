# %% [markdown]
# <a href="https://colab.research.google.com/github/VincentLin95/data-science-bootcamp-8/blob/main/Python/HW03%20-%20API%20Requesting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# import library
import requests
import time
import pandas as pd
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# API requesting
url = "http://universities.hipolabs.com/search?country=United+States"
name = []
domain = []
webpage = []

for i in range(30):
    resp = requests.get(url)
    if resp.status_code == 200:
        json_data = resp.json()
        name.append(json_data[i]["name"])
        domain.append(json_data[i]["domains"])
        webpage.append(json_data[i]["web_pages"])
    else:
        name.append(json_data["error"])
        domain.append(json_data["error"])
        webpage.append(json_data["error"])

time.sleep(1)

# create dataframe
USuniversitylist = pd.DataFrame(data= {
    "Name": name,
    "Domain": domain,
    "Webpage": webpage
})
USuniversitylist = USuniversitylist.style.hide_index()
USuniversitylist
# Out:
# <style type="text/css">
# </style>
# <table id="T_ac940" class="dataframe">
#   <thead>
#     <tr>
#       <th id="T_ac940_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_ac940_level0_col1" class="col_heading level0 col1" >Domain</th>
#       <th id="T_ac940_level0_col2" class="col_heading level0 col2" >Webpage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_ac940_row0_col0" class="data row0 col0" >Marywood University</td>
#       <td id="T_ac940_row0_col1" class="data row0 col1" >['marywood.edu']</td>
#       <td id="T_ac940_row0_col2" class="data row0 col2" >['http://www.marywood.edu']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row1_col0" class="data row1 col0" >Lindenwood University</td>
#       <td id="T_ac940_row1_col1" class="data row1 col1" >['lindenwood.edu']</td>
#       <td id="T_ac940_row1_col2" class="data row1 col2" >['http://www.lindenwood.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row2_col0" class="data row2 col0" >Sullivan University</td>
#       <td id="T_ac940_row2_col1" class="data row2 col1" >['sullivan.edu']</td>
#       <td id="T_ac940_row2_col2" class="data row2 col2" >['https://sullivan.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row3_col0" class="data row3 col0" >Florida State College at Jacksonville</td>
#       <td id="T_ac940_row3_col1" class="data row3 col1" >['fscj.edu']</td>
#       <td id="T_ac940_row3_col2" class="data row3 col2" >['https://www.fscj.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row4_col0" class="data row4 col0" >Xavier University</td>
#       <td id="T_ac940_row4_col1" class="data row4 col1" >['xavier.edu']</td>
#       <td id="T_ac940_row4_col2" class="data row4 col2" >['https://www.xavier.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row5_col0" class="data row5 col0" >Tusculum College</td>
#       <td id="T_ac940_row5_col1" class="data row5 col1" >['tusculum.edu']</td>
#       <td id="T_ac940_row5_col2" class="data row5 col2" >['https://home.tusculum.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row6_col0" class="data row6 col0" >Claremont School of Theology</td>
#       <td id="T_ac940_row6_col1" class="data row6 col1" >['cst.edu']</td>
#       <td id="T_ac940_row6_col2" class="data row6 col2" >['https://cst.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row7_col0" class="data row7 col0" >Columbia College (SC)</td>
#       <td id="T_ac940_row7_col1" class="data row7 col1" >['columbiasc.edu']</td>
#       <td id="T_ac940_row7_col2" class="data row7 col2" >['https://www.columbiasc.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row8_col0" class="data row8 col0" >Chabot-Las Positas Community College District</td>
#       <td id="T_ac940_row8_col1" class="data row8 col1" >['clpccd.edu']</td>
#       <td id="T_ac940_row8_col2" class="data row8 col2" >['http://www.clpccd.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row9_col0" class="data row9 col0" >Keller Graduate School of Management</td>
#       <td id="T_ac940_row9_col1" class="data row9 col1" >['keller.edu']</td>
#       <td id="T_ac940_row9_col2" class="data row9 col2" >['https://www.keller.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row10_col0" class="data row10 col0" >Monroe College</td>
#       <td id="T_ac940_row10_col1" class="data row10 col1" >['monroecollege.edu']</td>
#       <td id="T_ac940_row10_col2" class="data row10 col2" >['https://monroecollege.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row11_col0" class="data row11 col0" >San Mateo County Community College District</td>
#       <td id="T_ac940_row11_col1" class="data row11 col1" >['smccd.edu']</td>
#       <td id="T_ac940_row11_col2" class="data row11 col2" >['https://smccd.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row12_col0" class="data row12 col0" >Los Rios Community College District</td>
#       <td id="T_ac940_row12_col1" class="data row12 col1" >['losrios.edu']</td>
#       <td id="T_ac940_row12_col2" class="data row12 col2" >['http://losrios.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row13_col0" class="data row13 col0" >DigiPen Institute of Technology</td>
#       <td id="T_ac940_row13_col1" class="data row13 col1" >['digipen.edu']</td>
#       <td id="T_ac940_row13_col2" class="data row13 col2" >['https://www.digipen.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row14_col0" class="data row14 col0" >University of Pittsburgh Medical Center</td>
#       <td id="T_ac940_row14_col1" class="data row14 col1" >['upmc.edu', 'upmc.com']</td>
#       <td id="T_ac940_row14_col2" class="data row14 col2" >['https://www.upmc.com/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row15_col0" class="data row15 col0" >Claremont Graduate University</td>
#       <td id="T_ac940_row15_col1" class="data row15 col1" >['cgu.edu']</td>
#       <td id="T_ac940_row15_col2" class="data row15 col2" >['https://www.cgu.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row16_col0" class="data row16 col0" >The University of Texas at Rio Grande Valley</td>
#       <td id="T_ac940_row16_col1" class="data row16 col1" >['utrgv.edu']</td>
#       <td id="T_ac940_row16_col2" class="data row16 col2" >['https://www.utrgv.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row17_col0" class="data row17 col0" >College of Mount Saint Vincent</td>
#       <td id="T_ac940_row17_col1" class="data row17 col1" >['mountsaintvincent.edu']</td>
#       <td id="T_ac940_row17_col2" class="data row17 col2" >['https://mountsaintvincent.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row18_col0" class="data row18 col0" >University of Arkansas System eVersity</td>
#       <td id="T_ac940_row18_col1" class="data row18 col1" >['uasys.edu']</td>
#       <td id="T_ac940_row18_col2" class="data row18 col2" >['https://www.uasys.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row19_col0" class="data row19 col0" >ECPI University</td>
#       <td id="T_ac940_row19_col1" class="data row19 col1" >['ecpi.edu']</td>
#       <td id="T_ac940_row19_col2" class="data row19 col2" >['https://www.ecpi.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row20_col0" class="data row20 col0" >University of Mary Washington</td>
#       <td id="T_ac940_row20_col1" class="data row20 col1" >['umw.edu']</td>
#       <td id="T_ac940_row20_col2" class="data row20 col2" >['https://www.umw.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row21_col0" class="data row21 col0" >Baldwin Wallace University</td>
#       <td id="T_ac940_row21_col1" class="data row21 col1" >['bw.edu']</td>
#       <td id="T_ac940_row21_col2" class="data row21 col2" >['https://www.bw.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row22_col0" class="data row22 col0" >California State University Channel Islands</td>
#       <td id="T_ac940_row22_col1" class="data row22 col1" >['csuci.edu']</td>
#       <td id="T_ac940_row22_col2" class="data row22 col2" >['https://www.csuci.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row23_col0" class="data row23 col0" >Brandman University</td>
#       <td id="T_ac940_row23_col1" class="data row23 col1" >['brandman.edu']</td>
#       <td id="T_ac940_row23_col2" class="data row23 col2" >['https://www.brandman.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row24_col0" class="data row24 col0" >United States Coast Guard Academy</td>
#       <td id="T_ac940_row24_col1" class="data row24 col1" >['uscga.edu']</td>
#       <td id="T_ac940_row24_col2" class="data row24 col2" >['http://www.uscga.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row25_col0" class="data row25 col0" >Athens State University</td>
#       <td id="T_ac940_row25_col1" class="data row25 col1" >['athens.edu']</td>
#       <td id="T_ac940_row25_col2" class="data row25 col2" >['http://www.athens.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940_row26_col0" class="data row26 col0" >The Scripps Research Institute</td>
#       <td id="T_ac940_row26_col1" class="data row26 col1" >['scripps.edu']</td>
#       <td id="T_ac940_row26_col2" class="data row26 col2" >['https://scripps.edu/']</td>
#     </tr>
#     <tr>
#       <td id="T_ac940
